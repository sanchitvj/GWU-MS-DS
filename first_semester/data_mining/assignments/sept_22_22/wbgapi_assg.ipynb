# %%
# !pip install wbgapi

# %%
import wbgapi as wb
# wb.source.info()

# %%
df = wb.data.DataFrame(['EN.ATM.CO2E.KT', 'NY.GDP.MKTP.PP.KD'], economy=wb.region.members('EUU'), time=range(1994, 2022))

# %%
df.head()
# Out:
#                                  YR1994        YR1995        YR1996  \
# economy series
# AUT     EN.ATM.CO2E.KT     5.828000e+04  6.118000e+04  6.490000e+04
#         NY.GDP.MKTP.PP.KD  3.129625e+11  3.213123e+11  3.288616e+11
# BEL     EN.ATM.CO2E.KT     1.149000e+05  1.145700e+05  1.194500e+05
#         NY.GDP.MKTP.PP.KD  3.740897e+11  3.830108e+11  3.880721e+11
# BGR     EN.ATM.CO2E.KT     5.372000e+04  5.488000e+04  5.530000e+04
#
#                                  YR1997        YR1998        YR1999  \
# economy series
# AUT     EN.ATM.CO2E.KT     6.422000e+04  6.467000e+04  6.305000e+04
#         NY.GDP.MKTP.PP.KD  3.357467e+11  3.477712e+11  3.601391e+11
# BEL     EN.ATM.CO2E.KT     1.166300e+05  1.194100e+05  1.155100e+05
#         NY.GDP.MKTP.PP.KD  4.027942e+11  4.106963e+11  4.252462e+11
# BGR     EN.ATM.CO2E.KT     5.299000e+04  5.048000e+04  4.432000e+04
#
#                                  YR2000        YR2001        YR2002  \
# economy series
# ...

# %%
df.to_csv("gdp_co2_eu.csv")
